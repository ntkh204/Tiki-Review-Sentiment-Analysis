# %%
import pandas as pd
import regex as re
import seaborn as sns
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from underthesea import word_tokenize

# %%
df = pd.read_csv('data/submit.csv', encoding= 'utf-8')
df.head()
# Out:
#          id                                      clean_content  class
# 0  16227189  hàng đóng gói cẩn thận sách không trầy xước tr...      0
# 1  19881830  sách rạch bìa đóng gói túi không hộp giấy vỏ k...      0
# 2   5289139  dịch vụ hàng quyển sách hài hàng lịch nhiệt tì...      0
# 3   3119396  sách cũ dơ nếp gấp dám thùng hàng xuất hàng đầ...      0
# 4   9254834          vết bẩn xước sách kèm bookmark rút nghiệm      0

# %% [markdown]
# NEGATIVE

# %%
df_notlike = df[df['class'] == 0 ]
wc_notlike = WordCloud(
    background_color='black',
    max_words=500
)
wc_notlike.generate(str(df_notlike['clean_content'].values))

# %%
plt.figure(figsize=(12, 12))
plt.imshow(wc_notlike, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# POSITIVE

# %%
df_like = df[df['class'] == 1]
wc_like = WordCloud(
    background_color='black',
    max_words=500
)
wc_like.generate(str(df_like['clean_content'].values))

# %%
plt.figure(figsize=(12, 12))
plt.imshow(wc_like, interpolation='bilinear')
plt.axis('off')
plt.show()
